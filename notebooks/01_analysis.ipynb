# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_parquet("../results/ablation_effects_time_matched.parquet")

# %%
df["status_severity"].value_counts(normalize=True).sort_index()
# Out:
# status_severity
# 2     0.000802
# 3     0.005914
# 4     0.030552
# 5     0.063169
# 6     0.030931
# 9     0.060257
# 10    0.698523
# 20    0.109850
# Name: proportion, dtype: float64
